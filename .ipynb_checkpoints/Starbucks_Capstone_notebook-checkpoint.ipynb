# %% [markdown]
# # Starbucks Capstone Challenge
#
# ### Introduction
#
# This data set contains simulated data that mimics customer behavior on the Starbucks rewards mobile app. Once every few days, Starbucks sends out an offer to users of the mobile app. An offer can be merely an advertisement for a drink or an actual offer such as a discount or BOGO (buy one get one free). Some users might not receive any offer during certain weeks.
#
# Not all users receive the same offer, and that is the challenge to solve with this data set.
#
# Your task is to combine transaction, demographic and offer data to determine which demographic groups respond best to which offer type. This data set is a simplified version of the real Starbucks app because the underlying simulator only has one product whereas Starbucks actually sells dozens of products.
#
# Every offer has a validity period before the offer expires. As an example, a BOGO offer might be valid for only 5 days. You'll see in the data set that informational offers have a validity period even though these ads are merely providing information about a product; for example, if an informational offer has 7 days of validity, you can assume the customer is feeling the influence of the offer for 7 days after receiving the advertisement.
#
# You'll be given transactional data showing user purchases made on the app including the timestamp of purchase and the amount of money spent on a purchase. This transactional data also has a record for each offer that a user receives as well as a record for when a user actually views the offer. There are also records for when a user completes an offer.
#
# Keep in mind as well that someone using the app might make a purchase through the app without having received an offer or seen an offer.
#
# ### Example
#
# To give an example, a user could receive a discount offer buy 10 dollars get 2 off on Monday. The offer is valid for 10 days from receipt. If the customer accumulates at least 10 dollars in purchases during the validity period, the customer completes the offer.
#
# However, there are a few things to watch out for in this data set. Customers do not opt into the offers that they receive; in other words, a user can receive an offer, never actually view the offer, and still complete the offer. For example, a user might receive the "buy 10 dollars get 2 dollars off offer", but the user never opens the offer during the 10 day validity period. The customer spends 15 dollars during those ten days. There will be an offer completion record in the data set; however, the customer was not influenced by the offer because the customer never viewed the offer.
#
# ### Cleaning
#
# This makes data cleaning especially important and tricky.
#
# You'll also want to take into account that some demographic groups will make purchases even if they don't receive an offer. From a business perspective, if a customer is going to make a 10 dollar purchase without an offer anyway, you wouldn't want to send a buy 10 dollars get 2 dollars off offer. You'll want to try to assess what a certain demographic group will buy when not receiving any offers.
#
# ### Final Advice
#
# Because this is a capstone project, you are free to analyze the data any way you see fit. For example, you could build a machine learning model that predicts how much someone will spend based on demographics and offer type. Or you could build a model that predicts whether or not someone will respond to an offer. Or, you don't need to build a machine learning model at all. You could develop a set of heuristics that determine what offer you should send to each customer (i.e., 75 percent of women customers who were 35 years old responded to offer A vs 40 percent from the same demographic to offer B, so send offer A).

# %% [markdown]
# # Data Sets
#
# The data is contained in three files:
#
# * portfolio.json - containing offer ids and meta data about each offer (duration, type, etc.)
# * profile.json - demographic data for each customer
# * transcript.json - records for transactions, offers received, offers viewed, and offers completed
#
# Here is the schema and explanation of each variable in the files:
#
# **portfolio.json**
# * id (string) - offer id
# * offer_type (string) - type of offer ie BOGO, discount, informational
# * difficulty (int) - minimum required spend to complete an offer
# * reward (int) - reward given for completing an offer
# * duration (int) - time for offer to be open, in days
# * channels (list of strings)
#
# **profile.json**
# * age (int) - age of the customer
# * became_member_on (int) - date when customer created an app account
# * gender (str) - gender of the customer (note some entries contain 'O' for other rather than M or F)
# * id (str) - customer id
# * income (float) - customer's income
#
# **transcript.json**
# * event (str) - record description (ie transaction, offer received, offer viewed, etc.)
# * person (str) - customer id
# * time (int) - time in hours since start of test. The data begins at time t=0
# * value - (dict of strings) - either an offer id or transaction amount depending on the record

# %%
import pandas as pd
import numpy as np
import math
from statistics import mean
from datetime import date
import json
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

import pickle

# read in the json files
portfolio = pd.read_json('data/portfolio.json', orient='records', lines=True)
profile = pd.read_json('data/profile.json', orient='records', lines=True)
transcript = pd.read_json('data/transcript.json', orient='records', lines=True)

# %% [markdown]
# ## 1. Data Exploration

# %% [markdown]
# ### A quick glance at our datasets:

# %%
# for the ease of reading the data, we can reorder the columns:
portfolio = portfolio[portfolio.columns[::-1]]

portfolio
# Out:
#                                  id     offer_type  duration  difficulty  \
# 0  ae264e3637204a6fb9bb56bc8210ddfd           bogo         7          10
# 1  4d5c57ea9a6940dd891ad53e9dbe8da0           bogo         5          10
# 2  3f207df678b143eea3cee63160fa8bed  informational         4           0
# 3  9b98b8c7a33c4b65b9aebfe6a799e6d9           bogo         7           5
# 4  0b1e1539f2cc45b7b9fa7c272da2e1d7       discount        10          20
# 5  2298d6c36e964ae4a3e7e9706d1fb8c2       discount         7           7
# 6  fafdcd668e3743c1bb461111dcafc2a4       discount        10          10
# 7  5a8bc65990b245e5a138643cd4eb9837  informational         3           0
# 8  f19421c1d4aa40978ebb69ca19b0e20d           bogo         5           5
# 9  2906b810c7d4411798c6938adc9daaa5       discount         7          10
#
#                        channels  reward
# 0       [email, mobile, social]      10
# 1  [web, email, mobile, social]      10
# 2          [web, email, mobile]       0
# ...

# %%
# Checking out 'profile' dataset:
profile
# Out:
#       gender  age                                id  became_member_on  \
# 0       None  118  68be06ca386d4c31939f3a4f0e3dd783          20170212
# 1          F   55  0610b486422d4921ae7d2bf64640c50b          20170715
# 2       None  118  38fe809add3b4fcf9315a9694bb96ff5          20180712
# 3          F   75  78afa995795e4d85b5d9ceeca43f5fef          20170509
# 4       None  118  a03223e636434f42ac4c3df47e8bac43          20170804
# ...      ...  ...                               ...               ...
# 16995      F   45  6d5f3a774f3d4714ab0c092238f3a1d7          20180604
# 16996      M   61  2cb4f97358b841b9a9773a7aa05a9d77          20180713
# 16997      M   49  01d26f638c274aa0b965d24cefe3183f          20170126
# 16998      F   83  9dc1421481194dcd9400aec7c9ae6366          20160307
# 16999      F   62  e4052622e5ba45a8b96b59aba68cf068          20170722
#
#          income
# 0           NaN
# 1      112000.0
# 2           NaN
# 3      100000.0
# 4           NaN
# ...         ...
# ...

# %%
# Checking out 'transcript' dataset:
transcript
# Out:
#                                   person           event  \
# 0       78afa995795e4d85b5d9ceeca43f5fef  offer received
# 1       a03223e636434f42ac4c3df47e8bac43  offer received
# 2       e2127556f4f64592b11af22de27a7932  offer received
# 3       8ec6ce2a7e7949b1bf142def7d0e0586  offer received
# 4       68617ca6246f4fbc85e91a2a49552598  offer received
# ...                                  ...             ...
# 306529  b3a1272bc9904337b331bf348c3e8c17     transaction
# 306530  68213b08d99a4ae1b0dcb72aebd9aa35     transaction
# 306531  a00058cf10334a308c68e7631c529907     transaction
# 306532  76ddbd6576844afe811f1a3c0fbb5bec     transaction
# 306533  c02b10e8752c4d8e9b73f918558531f7     transaction
#
#                                                    value  time
# 0       {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}     0
# 1       {'offer id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'}     0
# 2       {'offer id': '2906b810c7d4411798c6938adc9daaa5'}     0
# ...

# %% [markdown]
# ### Cleaning and processing 'transcript' dataset:

# %%
# modify the transcript data by unpacking the dictionary consisting column:
def df_unpack(transcript):
    """
    INPUT: 
        transcript (dataframe): pandas dataframe containing person, event, value, and time data
        
    OUTPUT:
        transcript_no_dict (dataframe): the same input data frame with the value column unpacked to 'tag' and 
        'id_amount' columns
    """
    transcript_no_dict = transcript.copy()
    
    # upacking the dictionaries in the column 'value'
    Idx=transcript_no_dict.set_index(['person',
                                      'event', 
                                      'time']).value.apply(pd.Series).stack().index
    transcript_no_dict = pd.DataFrame(transcript_no_dict.
                                      set_index(['person','event', 'time']).
                                      value.apply(pd.Series).stack().
                                      values.tolist(),index=Idx).reset_index()

    # reordering and renaming the columns:
    transcript_no_dict = transcript_no_dict[['person', 'event','level_3', 0, 'time']]
    transcript_no_dict.rename(columns={ "level_3": "tag", 0: "id_amount"}, inplace=True)
    transcript_no_dict['tag'] = transcript_no_dict['tag'].str.replace(' ', '_')
    
    return transcript_no_dict


# define a function that takes the unpacked transcipt df and returns rewards and transaction dataframes:
def rewards_transaction(transcript_no_dict):
    """
    INPUTS:
        transcript_no_dict (dataframe): The unpacked df with person, event, tag, id_amount and time columns
        
    OUTPUTS: 
        transaction_df_person (dataframe): filtered transaction data for each person from the input dataframe
        reward_df_person (dataframe): filtered reward data for each person from the input dataframe
    """
    # creating a separate transaction data for calculating sum of transactions for each unique user:
    transcript_transactions = transcript_no_dict[transcript_no_dict['event']=='transaction']
    transcript_transactions.loc[:, 'id_amount'] = transcript_transactions.loc[:, 'id_amount'].astype(float)
    transcript_transactions.rename(columns={ "id_amount": "transaction_amount"}, inplace=True)
    transaction_df_person = (transcript_transactions.groupby('person')[['transaction_amount']].sum())
    transaction_df_person.reset_index(inplace=True)
    
    # creating reward dataset group by person id:
    reward_df = transcript_no_dict[transcript_no_dict['tag']=='reward']
    reward_df.loc[:,'id_amount'] = reward_df.loc[:,'id_amount'].astype(int)
    reward_df.rename(columns={ "id_amount": "reward_received"}, inplace=True)
    reward_df_person = pd.DataFrame(reward_df.groupby('person')[['reward_received']].sum())
    reward_df_person.reset_index(inplace=True)
    
    return transaction_df_person, reward_df_person


# defining a function to return grouped datasets for each person including details about their engagements 
# with the offers:
def person_offer_id_df(transcript_no_dict):
    """
    INPUT:
        transcript_no_dict (dataframe): The unpacked df with person, event, tag, id_amount and time columns
        
    OUTPUT:
        transcript_offer_id (dataframe): offer id data set grouped by person, event and status
        person_offer (dataframe): data set including number of each event for each person
    """
    # creating a dataframe containing all the affer related events:
    transcript_offer = transcript_no_dict[transcript_no_dict['event']!='transaction']

    # creating offer id data set grouped by person, event and status:
    transcript_offer_id = transcript_offer[transcript_offer['tag']=='offer_id']
    transcript_offer_id.rename(columns={ "id_amount": "offer_id"}, inplace=True)

    # creating person-offer dataframe:
    person_offer = transcript_offer_id.groupby(['person', 'event'])['offer_id'].count().unstack()
    person_offer.reset_index(inplace=True)
    person_offer = person_offer[['person', 'offer received', 'offer viewed', 'offer completed']]
    
    return transcript_offer_id, person_offer

# %%
# use our df_unpack function to unpack transcript data:
transcript_no_dict = df_unpack(transcript)

# %%
# use our rewards_transaction() function to create our dataframes:
transaction_df_person, reward_df_person = rewards_transaction(transcript_no_dict)
# Out:
# E:\Software\anaconda3\lib\site-packages\pandas\core\indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# E:\Software\anaconda3\lib\site-packages\pandas\core\frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
transcript_offer_id, person_offer = person_offer_id_df(transcript_no_dict)

# %%
transcript_no_dict
# Out:
#                                   person           event       tag  \
# 0       78afa995795e4d85b5d9ceeca43f5fef  offer received  offer_id
# 1       a03223e636434f42ac4c3df47e8bac43  offer received  offer_id
# 2       e2127556f4f64592b11af22de27a7932  offer received  offer_id
# 3       8ec6ce2a7e7949b1bf142def7d0e0586  offer received  offer_id
# 4       68617ca6246f4fbc85e91a2a49552598  offer received  offer_id
# ...                                  ...             ...       ...
# 340108  b3a1272bc9904337b331bf348c3e8c17     transaction    amount
# 340109  68213b08d99a4ae1b0dcb72aebd9aa35     transaction    amount
# 340110  a00058cf10334a308c68e7631c529907     transaction    amount
# 340111  76ddbd6576844afe811f1a3c0fbb5bec     transaction    amount
# 340112  c02b10e8752c4d8e9b73f918558531f7     transaction    amount
#
#                                id_amount  time
# 0       9b98b8c7a33c4b65b9aebfe6a799e6d9     0
# 1       0b1e1539f2cc45b7b9fa7c272da2e1d7     0
# ...

# %%
transaction_df_person
# Out:
#                                  person  transaction_amount
# 0      0009655768c64bdeb2e877511632db8f              127.60
# 1      00116118485d4dfda04fdbaba9a87b5c                4.09
# 2      0011e0d4e6b944f998e987f904e8c1e5               79.46
# 3      0020c2b971eb4e9188eac86d93036a77              196.86
# 4      0020ccbbb6d84e358d3414a3ff76cffd              154.05
# ...                                 ...                 ...
# 16573  fff3ba4757bd42088c044ca26d73817a              580.98
# 16574  fff7576017104bcc8677a8d63322b5e1               29.94
# 16575  fff8957ea8b240a6b5e634b6ee8eafcf               12.15
# 16576  fffad4f4828548d1b5583907f2e9906b               88.83
# 16577  ffff82501cea40309d5fdd7edcca4a07              226.07
#
# [16578 rows x 2 columns]

# %%
reward_df_person
# Out:
#                                  person  reward_received
# 0      0009655768c64bdeb2e877511632db8f                9
# 1      0011e0d4e6b944f998e987f904e8c1e5               13
# 2      0020c2b971eb4e9188eac86d93036a77               14
# 3      0020ccbbb6d84e358d3414a3ff76cffd               13
# 4      003d66b6608740288d6cc97a6903f4f0                9
# ...                                 ...              ...
# 12769  fff29fb549084123bd046dbc5ceb4faa               47
# 12770  fff3ba4757bd42088c044ca26d73817a                9
# 12771  fff7576017104bcc8677a8d63322b5e1                9
# 12772  fffad4f4828548d1b5583907f2e9906b               15
# 12773  ffff82501cea40309d5fdd7edcca4a07               18
#
# [12774 rows x 2 columns]

# %%
transcript_offer_id
# Out:
#                                   person            event       tag  \
# 0       78afa995795e4d85b5d9ceeca43f5fef   offer received  offer_id
# 1       a03223e636434f42ac4c3df47e8bac43   offer received  offer_id
# 2       e2127556f4f64592b11af22de27a7932   offer received  offer_id
# 3       8ec6ce2a7e7949b1bf142def7d0e0586   offer received  offer_id
# 4       68617ca6246f4fbc85e91a2a49552598   offer received  offer_id
# ...                                  ...              ...       ...
# 340072  a6f84f4e976f44508c358cc9aba6d2b3  offer completed  offer_id
# 340082  b895c57e8cd047a8872ce02aa54759d6  offer completed  offer_id
# 340084  8dda575c2a1d44b9ac8e8b07b93d1f8e     offer viewed  offer_id
# 340086  8431c16f8e1d440880db371a68f82dd0  offer completed  offer_id
# 340105  24f56b5e1849462093931b164eb803b5  offer completed  offer_id
#
#                                 offer_id  time
# 0       9b98b8c7a33c4b65b9aebfe6a799e6d9     0
# 1       0b1e1539f2cc45b7b9fa7c272da2e1d7     0
# ...

# %% [markdown]
# ### Determine which demographic group responds best to which offer type.

# %%
# In order to have a more perspective on the characteristics of responders to each offer, 
# we need to create a dataset grouped by the unique offer ids and containing detailed statistics 
# about the responders to that offer. 

# creating an offer-profile data set for the completed offers including all the users details
offer_profile = pd.merge(profile, transcript_offer_id, how='right', on='person')
offer_profile = offer_profile[['offer_id', 'person', 'gender', 'age', 
                               'became_member_on', 'income', 'event']]
offer_person = offer_profile[offer_profile['event']=='offer completed']

# convert the date of membership to timestamp
offer_person['became_member_on'] = pd.to_datetime(offer_person['became_member_on'], format='%Y%m%d')

# calculate the years of membership and replace it with the membership date column:
offer_person['years_of_membership'] = offer_person['became_member_on'].apply(lambda x: date.today().year - x.year)
offer_person.drop('became_member_on', axis=1, inplace=True)

# creating an age category for more interpretation:
bins = np.arange(1, 11) * 10
offer_person['age_category'] = np.digitize(offer_person.age, bins, right=True)
offer_person = offer_person[['offer_id', 'gender', 'age','age_category', 'income', 'years_of_membership']]
offer_person['age_category'] = offer_person['age_category'].map({1:'10-20', 2:'20-30', 3:'30-40', 4:'40-50',
                                 5:'50-60', 6:'60-70', 7:'70-80', 8:'80-90', 9:'90-100'})
# Out:
# <ipython-input-248-b7be69ee99f2>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   offer_person['became_member_on'] = pd.to_datetime(offer_person['became_member_on'], format='%Y%m%d')
# <ipython-input-248-b7be69ee99f2>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   offer_person['years_of_membership'] = offer_person['became_member_on'].apply(lambda x: date.today().year - x.year)
# E:\Software\anaconda3\lib\site-packages\pandas\core\frame.py:4305: SettingWithCopyWarning:
# ...

# %%
offer_person
# Out:
#                                 offer_id gender  age age_category   income  \
# 12656   2906b810c7d4411798c6938adc9daaa5      M   42        40-50  96000.0
# 12667   fafdcd668e3743c1bb461111dcafc2a4      F   39        30-40  67000.0
# 12673   9b98b8c7a33c4b65b9aebfe6a799e6d9      M   52        50-60  72000.0
# 12683   ae264e3637204a6fb9bb56bc8210ddfd      M   37        30-40  92000.0
# 12687   4d5c57ea9a6940dd891ad53e9dbe8da0      M   48        40-50  62000.0
# ...                                  ...    ...  ...          ...      ...
# 167573  2298d6c36e964ae4a3e7e9706d1fb8c2      M   56        50-60  61000.0
# 167576  2298d6c36e964ae4a3e7e9706d1fb8c2   None  118          NaN      NaN
# 167577  fafdcd668e3743c1bb461111dcafc2a4   None  118          NaN      NaN
# 167579  fafdcd668e3743c1bb461111dcafc2a4      M   39        30-40  39000.0
# 167580  fafdcd668e3743c1bb461111dcafc2a4      F   48        40-50  80000.0
#
#         years_of_membership
# 12656                     5
# ...

# %% [markdown]
# ### Visualizing the offer-person statistics:

# %%
# defining a function to return a dataset including age categories and gender and their prtions:
def gender_age_offer(offer_id, df=offer_person):
    """
    INPUT:
        offer_id (str): The offer id we want to get details from
        df (dataframe): The data frame consisting data about ids and users
        
    OUTPUT:
        counts (dataframe): a dataset consisting of age categories and the gender of 
        responder to the given offer id
    """
    gender_age = df[df['offer_id']==offer_id][['gender', 'age_category']]
    
    counts = gender_age.groupby(['age_category', 'gender']).age_category.count().unstack()
    
    off_per_count = df.groupby(['age_category', 'gender']).age_category.count().unstack()

    counts['Female %'] = round((100 * counts['F']/off_per_count.loc[counts.index,'F']),1)
    counts['Male %'] = round((100 * counts['M']/off_per_count.loc[counts.index,'M']),1)
    counts['Other %'] = round((100 * counts['O']/off_per_count.loc[counts.index,'O']),1)

    
    return counts

# %%
# iterating in the data sets to visualize the details of responders to each offer:
for i in list(offer_person['offer_id'].unique()):
    counts = gender_age_offer(i)
    
    ot = portfolio[portfolio.id==i].iloc[0, 1]
    ch = str(portfolio[portfolio.id==i].iloc[0, -2])
    
    fig, axes = plt.subplots(nrows=1, ncols=2)

    counts.iloc[:,:3].plot(kind='bar',ax=axes[0], title='Number of Responders to the Offer', 
                           figsize=(15,5), legend=False, stacked=True, 
                           color=['#E98F17', '#094B7D', '#B4B87E'])
    
    
    counts.iloc[:,-3:].plot(kind='bar',ax=axes[1],figsize=(15,5), 
                            title='Percentage of the Whole Sample', 
                            legend=False, stacked=True,
                           color=['#E98F17', '#094B7D', '#B4B87E'])

    fig.suptitle('Offer ID: '+i+'        Offer Type: '+ot+'      Channels: '+ch, fontweight='bold')
    fig.legend(labels=['Female', 'Male', 'Other'])
    
        
    save_ad = i+'.png'
    plt.savefig(save_ad, dpi=300)
    
    plt.show()

# %%
# we noticed that there were only 8 unique offer ids in the offer_person dataset
# We should investigate to see what is missing:
missing = list(np.setdiff1d(portfolio.id.unique(), offer_person.offer_id.unique()))
portfolio[portfolio.id.isin(missing)]
# Out:
#                                  id     offer_type  duration  difficulty  \
# 2  3f207df678b143eea3cee63160fa8bed  informational         4           0
# 7  5a8bc65990b245e5a138643cd4eb9837  informational         3           0
#
#                   channels  reward
# 2     [web, email, mobile]       0
# 7  [email, mobile, social]       0

# %% [markdown]
# #### These two offers are informational offers with no rewards and non of the users has completed any of these.

# %%
# we have some users in our data frame that has completed the offers before viewing them 
# to filter out these users, we need to know the time of viewing and time of completion for each offer

# defining a fuction that finds each persons average view time and action time:
def get_times(person_id, df=transcript_offer_id):
    """
    INPUT: 
        person_id (string): the person id for whom we want to extract the timings for
        df (dataframe): a data frame with person , event, and offer_id data
        
    OUTPUT: 
        view_time_mean (int): the average time needed for the person to view the offer since it was received
        action_time_mean (int): the average time needed for the person to act on the viewed offer
    """
    p1 = df[df['person']== person_id]
    
    view_time_list = []
    action_time_list = []
    
    for i in list(p1['offer_id'].unique()):
        event_offer = list(p1[p1['offer_id']==i]['event'])
                
        if 'offer viewed' in event_offer:
            off_rec_time = p1[(p1['offer_id']==i) & 
                          (p1['event']=='offer received')]['time'].values[0]
            off_vie_time = p1[(p1['offer_id']==i) & 
                          (p1['event']=='offer viewed')]['time'].values[0]
            
            vt = off_vie_time - off_rec_time
        
        else:
            vt = float('NaN')
        
        if 'offer viewed' in event_offer and 'offer completed' in event_offer:
            off_com_time = p1[(p1['offer_id']==i) & 
                              (p1['event']=='offer completed')]['time'].values[0]
            
            at = off_com_time - off_vie_time
        else:
            at = float('NaN')
        
        # if view time is NaN, we'll know it does not exist, so we will not add it to our list
        # also negative times are not usefull for us so:
        if math.isnan(vt)==False and vt >= 0:
            view_time_list.append(vt)
        else:
            pass

        # negative action time means that some of offer completions were done before viewing the offer
        # so we will not add them to our list
        if math.isnan(at)==False and at >= 0:
            action_time_list.append(at)
        else:
            pass
    
    # since we can not get the mean of an empty list or a list with only NaN values:
    try:
        view_time_mean = mean(view_time_list)
    except:
        view_time_mean = float('NaN')
    
    try:
        action_time_mean = mean(action_time_list)
    except:
        action_time_mean = float('NaN')
        
    
    return view_time_mean, action_time_mean


# adding 'view time' and 'action time' to person_offer dataset:
def view_action_time_add(person_offer):
    """
    INPUT: 
        person_offer (dataframe): data set including number of each event for each person
        
    OUTPUT:
        person_offer (dataframe): input data frame including added view_time and action_time columns
    """
    # creating the view time and action time columns using get_times() function:
    view_times = []
    action_times = []
    for i in person_offer['person']:
        view_times.append(get_times(i)[0])
        action_times.append(get_times(i)[1])
    # adding the new lists to our person_offer df:
    person_offer['view_time'] = view_times
    person_offer['action_time'] = action_times
    
    return person_offer

# %%
person_offer = view_action_time_add(person_offer)

# %%
person_offer
# Out:
# event                            person  offer received  offer viewed  \
# 0      0009655768c64bdeb2e877511632db8f             5.0           4.0
# 1      00116118485d4dfda04fdbaba9a87b5c             2.0           2.0
# 2      0011e0d4e6b944f998e987f904e8c1e5             5.0           5.0
# 3      0020c2b971eb4e9188eac86d93036a77             5.0           3.0
# 4      0020ccbbb6d84e358d3414a3ff76cffd             4.0           4.0
# ...                                 ...             ...           ...
# 16989  fff3ba4757bd42088c044ca26d73817a             6.0           3.0
# 16990  fff7576017104bcc8677a8d63322b5e1             5.0           4.0
# 16991  fff8957ea8b240a6b5e634b6ee8eafcf             3.0           2.0
# 16992  fffad4f4828548d1b5583907f2e9906b             4.0           4.0
# 16993  ffff82501cea40309d5fdd7edcca4a07             6.0           6.0
#
# event  offer completed  view_time  action_time
# 0                  3.0       36.0          NaN
# ...

# %%
# merging all 3 user-based dataframes to have a more detailed data on 
# each persons interaction with the offers:
merged_df = pd.merge(reward_df_person, transaction_df_person, how='right', on= 'person')
person_merged = pd.merge(merged_df, person_offer, how='right', on='person')
person_merged
# Out:
#                                  person  reward_received  transaction_amount  \
# 0      0009655768c64bdeb2e877511632db8f              9.0              127.60
# 1      00116118485d4dfda04fdbaba9a87b5c              NaN                4.09
# 2      0011e0d4e6b944f998e987f904e8c1e5             13.0               79.46
# 3      0020c2b971eb4e9188eac86d93036a77             14.0              196.86
# 4      0020ccbbb6d84e358d3414a3ff76cffd             13.0              154.05
# ...                                 ...              ...                 ...
# 16989  fff3ba4757bd42088c044ca26d73817a              9.0              580.98
# 16990  fff7576017104bcc8677a8d63322b5e1              9.0               29.94
# 16991  fff8957ea8b240a6b5e634b6ee8eafcf              NaN               12.15
# 16992  fffad4f4828548d1b5583907f2e9906b             15.0               88.83
# 16993  ffff82501cea40309d5fdd7edcca4a07             18.0              226.07
#
# ...

# %% [markdown]
# ### Create a dataframe Including all the data we have on user ids:

# %%
# first start by checking why there are 6 missing user id s in the merged df!
missing_ids = list(np.setdiff1d(np.array(profile['id']), 
                                np.array(person_merged['person'])))
transcript_no_dict[transcript_no_dict['person'].isin(missing_ids)]['event'].unique()
# Out:
# array(['transaction'], dtype=object)

# %% [markdown]
# We clearly see that the persons who are not in the final merged df, all have done transactions without getting an offer, so it's better to leave it as it is.

# %% [markdown]
# ### Merge the profile dataset with our recent data frame

# %%
# Now we sort and rename the profile df to prepare it for the merge:
prof = profile[['id','gender', 'age','became_member_on', 'income']]
prof.rename(columns={ "id": "person"}, inplace=True)

# merge and reorder the datasets:
profile_merged = pd.merge(person_merged, prof, how='right', on= 'person')
profile_merged = profile_merged[['person', 'gender','age', 'became_member_on', 
                                 'income', 'view_time', 'action_time','offer received', 
                                 'offer viewed','transaction_amount', 'reward_received', 
                                 'offer completed']]

# %%
profile_merged
# Out:
#                                  person gender  age  became_member_on  \
# 0      68be06ca386d4c31939f3a4f0e3dd783   None  118          20170212
# 1      0610b486422d4921ae7d2bf64640c50b      F   55          20170715
# 2      38fe809add3b4fcf9315a9694bb96ff5   None  118          20180712
# 3      78afa995795e4d85b5d9ceeca43f5fef      F   75          20170509
# 4      a03223e636434f42ac4c3df47e8bac43   None  118          20170804
# ...                                 ...    ...  ...               ...
# 16995  6d5f3a774f3d4714ab0c092238f3a1d7      F   45          20180604
# 16996  2cb4f97358b841b9a9773a7aa05a9d77      M   61          20180713
# 16997  01d26f638c274aa0b965d24cefe3183f      M   49          20170126
# 16998  9dc1421481194dcd9400aec7c9ae6366      F   83          20160307
# 16999  e4052622e5ba45a8b96b59aba68cf068      F   62          20170722
#
#          income  view_time  action_time  offer received  offer viewed  \
# ...

# %% [markdown]
# ### Cleaning the merged dataframe:

# %%
# Now we should filter out the rows with existing 'offer completed' values and NaN 'action time' value. 
# These are users who completed an offer before viewing it (with reference to our get_times() function 
# in which we put NaN for all negative time differences between view time and action time) so they would
# do it regardless of viewing the offer.
# droping the rows containing non-engaged users
not_engaged = list((profile_merged[(profile_merged['offer completed'].isnull()==False) & 
              (profile_merged['action_time'].
               isnull()==True)])['person'])
profile_merged_clean = profile_merged[~profile_merged['person'].isin(not_engaged)]

# impute the nan values in 'offer completed' by 0:
profile_merged_clean['offer completed'].fillna(0, inplace=True)

# We can impute the missing age values with the mean:
profile_merged_clean['age'] = np.where(profile_merged_clean['age']==118, 
                                       float('NaN'), profile_merged_clean['age'])
profile_merged_clean['age'].fillna(round(profile_merged_clean['age'].mean(),0), inplace=True)

# we can do the same imputation for income column:
profile_merged_clean['income'].fillna(round(profile_merged_clean['income'].mean(),0), 
                                      inplace=True)

# also adding a new N/A category for the gender column:
profile_merged_clean['gender'].fillna('N/A', inplace=True)

# imputing zero for all the missing values in the following columns:
profile_merged_clean['reward_received'].fillna(0, inplace=True)
profile_merged_clean['transaction_amount'].fillna(0, inplace=True)
profile_merged_clean['offer viewed'].fillna(0, inplace=True)
profile_merged_clean['offer received'].fillna(0, inplace=True)

# since we do not need the view_time and action_time, and thier existence only adds up more null values
# to the dataset, we choose to delete them for now:
profile_merged_clean.drop(['view_time', 'action_time'], axis=1, inplace=True)

# There are still some users in our data set who has completed offers that they have not even viewed
# with these data in our dataset, we are increasing the fake transaction amount risen by these unrelated 
# offer completions. so it's more accurate to delete these.
to_drop = list(profile_merged_clean[profile_merged_clean['offer completed'] > profile_merged_clean['offer viewed']]['person'])
profile_merged_clean = profile_merged_clean[~profile_merged_clean.person.isin(to_drop)]
# Out:
# E:\Software\anaconda3\lib\site-packages\pandas\core\series.py:4433: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(
# <ipython-input-54-8dc03b0d5f86>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   profile_merged_clean['age'] = np.where(profile_merged_clean['age']==118,
# E:\Software\anaconda3\lib\site-packages\pandas\core\series.py:4433: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
profile_merged_clean
# Out:
#                                  person gender   age  became_member_on  \
# 0      68be06ca386d4c31939f3a4f0e3dd783    N/A  54.0          20170212
# 2      38fe809add3b4fcf9315a9694bb96ff5    N/A  54.0          20180712
# 3      78afa995795e4d85b5d9ceeca43f5fef      F  75.0          20170509
# 4      a03223e636434f42ac4c3df47e8bac43    N/A  54.0          20170804
# 5      e2127556f4f64592b11af22de27a7932      M  68.0          20180426
# ...                                 ...    ...   ...               ...
# 16994  c02b10e8752c4d8e9b73f918558531f7    N/A  54.0          20151211
# 16995  6d5f3a774f3d4714ab0c092238f3a1d7      F  45.0          20180604
# 16997  01d26f638c274aa0b965d24cefe3183f      M  49.0          20170126
# 16998  9dc1421481194dcd9400aec7c9ae6366      F  83.0          20160307
# 16999  e4052622e5ba45a8b96b59aba68cf068      F  62.0          20170722
#
#          income  offer received  offer viewed  transaction_amount  \
# ...

# %% [markdown]
# ### Adding  number of offers each user has received,  grouped by the offer id

# %%
# creating a person-offer data set:
transcript_offer_received = transcript_offer_id[transcript_offer_id['event']=='offer received']
person_offer_comp = transcript_offer_received.groupby(['person', 'offer_id'])['event'].count().unstack()

# %%
# merging the person_offer_comp dataset with our previous dataset:
df = pd.merge(person_offer_comp, profile_merged_clean, how='right', on= 'person')

# %%
df
# Out:
#                                  person  0b1e1539f2cc45b7b9fa7c272da2e1d7  \
# 0      68be06ca386d4c31939f3a4f0e3dd783                               1.0
# 1      38fe809add3b4fcf9315a9694bb96ff5                               NaN
# 2      78afa995795e4d85b5d9ceeca43f5fef                               NaN
# 3      a03223e636434f42ac4c3df47e8bac43                               3.0
# 4      e2127556f4f64592b11af22de27a7932                               NaN
# ...                                 ...                               ...
# 14031  c02b10e8752c4d8e9b73f918558531f7                               1.0
# 14032  6d5f3a774f3d4714ab0c092238f3a1d7                               NaN
# 14033  01d26f638c274aa0b965d24cefe3183f                               1.0
# 14034  9dc1421481194dcd9400aec7c9ae6366                               NaN
# 14035  e4052622e5ba45a8b96b59aba68cf068                               NaN
#
#        2298d6c36e964ae4a3e7e9706d1fb8c2  2906b810c7d4411798c6938adc9daaa5  \
# ...

# %% [markdown]
# ### Cleaning the final dataset and prepare for modeling
# We want to create a model to predict how many offers a user would complete, given the type of offer, details of the user and other metrics. so we should finalize data cleaning, numerate all categorical values, and prepare for modeling.

# %%
# Imputing zeros for all NaN values in the completed offers section:
df.iloc[:, 1:11] = df.iloc[:, 1:11].fillna(0)

# change gender into dummy variables and add to the dataset:
gender_dummy = pd.get_dummies(df['gender'], drop_first=True)
df.drop('gender', axis=1, inplace=True)
df[['Gender_male', 'Gender_unknown', 'Gender_other']] = gender_dummy

# convert the date of membership to timestamp
df['became_member_on'] = pd.to_datetime(df['became_member_on'], format='%Y%m%d')

# calculate the years of membership and replace it with the membership date column:
df['years_of_membership'] = df['became_member_on'].apply(lambda x: date.today().year - x.year)
df.drop('became_member_on', axis=1, inplace=True)

df_cleaned = df[['person', '2298d6c36e964ae4a3e7e9706d1fb8c2',
                 '2906b810c7d4411798c6938adc9daaa5', '3f207df678b143eea3cee63160fa8bed',
                 '4d5c57ea9a6940dd891ad53e9dbe8da0', '5a8bc65990b245e5a138643cd4eb9837',
                 '9b98b8c7a33c4b65b9aebfe6a799e6d9', 'ae264e3637204a6fb9bb56bc8210ddfd', 
                 'f19421c1d4aa40978ebb69ca19b0e20d', 'fafdcd668e3743c1bb461111dcafc2a4', 
                 'Gender_male', 'Gender_other', 'Gender_unknown','age', 
                 'income', 'years_of_membership', 'offer received', 'offer viewed', 
                 'transaction_amount', 'reward_received', 'offer completed']]

# %%
df_cleaned
# Out:
#                                  person  2298d6c36e964ae4a3e7e9706d1fb8c2  \
# 0      68be06ca386d4c31939f3a4f0e3dd783                               1.0
# 1      38fe809add3b4fcf9315a9694bb96ff5                               0.0
# 2      78afa995795e4d85b5d9ceeca43f5fef                               0.0
# 3      a03223e636434f42ac4c3df47e8bac43                               0.0
# 4      e2127556f4f64592b11af22de27a7932                               0.0
# ...                                 ...                               ...
# 14031  c02b10e8752c4d8e9b73f918558531f7                               1.0
# 14032  6d5f3a774f3d4714ab0c092238f3a1d7                               1.0
# 14033  01d26f638c274aa0b965d24cefe3183f                               0.0
# 14034  9dc1421481194dcd9400aec7c9ae6366                               0.0
# 14035  e4052622e5ba45a8b96b59aba68cf068                               1.0
#
#        2906b810c7d4411798c6938adc9daaa5  3f207df678b143eea3cee63160fa8bed  \
# ...

# %% [markdown]
# ### Checking for outliers:

# %%
# The most possible column is 'transaction_amount':
plt.hist(df_cleaned['transaction_amount'], color='teal')
plt.title('Transaction Amount Distribution', fontsize=16)

plt.savefig('transaction_outliers', dpi=300)

# %%
# and also 'income' column is another possiblity for outliers:
plt.hist(df_cleaned['income'], color='goldenrod')
plt.title('Income Distribution', fontsize=16)

plt.savefig('income_outliers', dpi=300)

# %%
# We notice there are a few outliers with large amounts of transaction
# it is better to remove them to have a more accurate model
# to safely remove the outliers, we should conservatively start by removing a small percentile from above:
q = df_cleaned['transaction_amount'].quantile(0.97)
df_cleaned.drop(df_cleaned[df_cleaned['transaction_amount']>q].index, inplace=True)

# Now we can check again to see how it changed our distribution:
plt.hist(df_cleaned['transaction_amount'], color='teal')
plt.title('Transaction Amount Distribution', fontsize=16)

plt.savefig('transaction_no_outliers.png', dpi=300)
plt.show()
# Out:
# E:\Software\anaconda3\lib\site-packages\pandas\core\frame.py:4305: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %% [markdown]
# ### Split the data and train our model:

# %%
# asigning the features and targets:
X = df_cleaned.iloc[:,1:-1]
y = df_cleaned['offer completed']

# splitting train and test data:
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
scoring = make_scorer(r2_score)
g_cv = GridSearchCV(RandomForestRegressor(random_state=0),
              param_grid={'max_leaf_nodes': [200,300], 
                          'max_depth': [15,30,40],
                          'min_samples_leaf': [10,15,20]},
              scoring=scoring, cv=10, refit=True)

g_cv.fit(X_train, y_train)
g_cv.best_params_

result = g_cv.cv_results_

r2_score(y_test, g_cv.best_estimator_.predict(X_test))
# Out:
# 0.9741449293279639

# %%
g_cv.best_params_
# Out:
# {'max_depth': 15, 'max_leaf_nodes': 300, 'min_samples_leaf': 10}

# %%
rf_regressor = RandomForestRegressor(n_estimators=200, max_leaf_nodes=300, 
                                     max_depth=15, min_samples_leaf=10)
rf_regressor.fit(X_train, y_train)

rf_regressor.score(X_train, y_train)
# Out:
# 0.9810745706685221

# %%
rf_regressor.score(X_test, y_test)
# Out:
# 0.9730219058864473

# %% [raw]
# ### Checking the errors:

# %%
y_pred = rf_regressor.predict(X_test)

from sklearn import metrics

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.12836684402568674
# Mean Squared Error: 0.06776717806646412
# Root Mean Squared Error: 0.2603212977581053

# %% [markdown]
# ### Checking the accuracy visually:

# %%
plt.scatter(y_test, y_pred, alpha=0.15, color='coral')
plt.title('Model Prediction Accuracy')
plt.xlabel('Test Targets')
plt.ylabel('Predicted Values')

plt.savefig('model_accuracy.png',dpi=300)

# %% [markdown]
# ### Exporting the model:

# %%
filename = 'starbucks_model.sav'
pickle.dump(rf_regressor, open(filename, 'wb'))
